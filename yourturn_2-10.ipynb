# %%
egfr = 85
d = {0:'正常', 1:'1 期', 2:'2 期', 3:'3 期', 4:'4 期', 5:'5 期'}
a = 0
a += int(100 >= egfr >= 90)
a += int(90 > egfr >= 60) * 2
a += int(60 > egfr >= 30) * 3
a += int(30 > egfr >= 15) * 4
a += int(egfr < 15) * 5
print(d[a])
