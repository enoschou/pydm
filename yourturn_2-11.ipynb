# %% [markdown]
# ## 1

# %%
egfr = 26
if egfr > 100:
    print('正常')
elif egfr >= 90:
    print('1 期')
elif egfr >= 60:
    print('2 期')
elif egfr >= 30:
    print('3 期')
elif egfr >= 15:
    print('4 期')
elif egfr == 0:
    print('may be system error?')
else:
    print('5 期')

# %% [markdown]
# ## 2

# %%
from random import choice
computer = choice(['剪刀', '石頭', '布'])
user = '石頭'

if computer == '剪刀':
    print('user win!')
elif computer == '石頭':
    print('tie.')
else:
    print('user lose.')
