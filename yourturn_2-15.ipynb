# %%
s = 'How about studying Python'
q = s.split()
print(q)
target = 'studying'
for i, v in enumerate(q):
    if v == target:
        print(f'{target} at {i}')

# %%
s = 'How about studying Python'
q = s.split()
print(q)
target = 'studying'
for i in range(len(q)):
    if q[i] == target:
        print(f'{target} at {i}')
