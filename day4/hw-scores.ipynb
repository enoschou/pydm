# %% [markdown]
# # Homework Scores
#
# ## Tech
# > Loop
# > if-elif-else
# > Sort
#
# ## Tasks
# 學生分數儲存方式如下 `scores = [11, 22, 33, 44, 55, 77, 99, 88, 66]`，請將分數排序，再逐行輸出及格最低分與不及格最高分。若沒有學生及格，則及格最低分改輸出為 `worst case`；若沒有學生不及格，則不及格最高分改輸出為 `best case`。
# 1. 以 `for` 完成
# 2. 以 `while` 完成
#
# ## Output
# ```text
# # case 1
# # scores = [11, 22, 33, 44, 55, 77, 99, 88, 66]
# 66
# 55
#
# # case 2
# # scores = [78, 63]
# 63
# best case
#
# # case 3
# # scores = [13]
# worst case
# 13
# ```
