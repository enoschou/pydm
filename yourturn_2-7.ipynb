# %% [markdown]
# ## 1

# %%
a = 100
b = 150
c = 200

print(a > 50 or b > 100 and c > 300)

# %%
print((a > 50 or b > 100) and c > 300)

# %% [markdown]
# ## 2

# %%
print(2 ** 3 ** 2)

# %%
print((2 ** 3) ** 2)
