# %%
class test:
    
    def __init__(self):
        self.value = 10
        self._value = 20
        self.__value = 30
    
    def inc(self):
        self.value += 1
        print(self.value)
    
    def _inc(self):
        self._value += 1
        print(self._value)
        
    def __inc(self):
        self.__value += 1
        print(self.__value)

# %%
t = test()
t.inc()
t._inc()
t.__inc()

# %%
print(dir(t))
