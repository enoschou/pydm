# %%
a = [1, 2, 3]

print(a[3])
print(a[0] / 0)
print(max(a[0]))

# %%
a = [1, 2, 3]

try:
    print(a[3])
except Exception as e:
    print(f'{type(e).__name__}: {e}')

# %%
a = [1, 2, 3]

try:
    print(a[0] / 0)
except Exception as e:
    print(f'{type(e).__name__}: {e}')

# %%
a = [1, 2, 3]

try:
    print(max(a[0]))
except Exception as e:
    print(f'{type(e).__name__}: {e}')

# %%
a = [1, 2, 3]

try:
    print(a[3])
except (IndexError, ZeroDivisionError, TypeError) as e:
    print(f'{type(e).__name__}: {e}')

# %%
a = [1, 2, 3]

try:
    print(a[0] / 0)
except (IndexError, ZeroDivisionError, TypeError) as e:
    print(f'{type(e).__name__}: {e}')

# %%
a = [1, 2, 3]

try:
    print(max(a[0]))
except (IndexError, ZeroDivisionError, TypeError) as e:
    print(f'{type(e).__name__}: {e}')
