# %%
s = ['David', 'Joe', 'Jack', 'Lance']
count = 0
for x in s:
    if x[0] == 'J':
        count += 1
print(f'{count} J people')

# %%
s = ['David', 'Joe', 'Jack', 'Lance']
count = 0
for x in s:
    if x.find('J') == 0:
        count += 1
print(f'{count} J people')
