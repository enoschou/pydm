# %% [markdown]
# ## Run Python 4

# %%
from runpython3 import Trees2

# %%
print(Trees2.count('trees', 'train', 'DR'))

# %%
from runpython5 import Trees2

# %%
print(Trees2.count('trees', 'train', 'DR'))

# %%
from runpython6 import Trees2

# %%
print(Trees2.count('trees', 'train', 'DR'))
