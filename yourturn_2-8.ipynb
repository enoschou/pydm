# %% [markdown]
# ## 1

# %% [markdown]
# ## a

# %%
a = 1
b = 1
print(a is b)
print(a is 1)

# %%
print(id(a), id(b), id(1))

# %% [markdown]
# ## b

# %%
a = 1024
b = 1024
print(a is b)
print(a is 1024)

# %%
print(id(a), id(b), id(1024))

# %% [markdown]
# ## c

# %%
a = None
b = None
print(a is b)
print(a is None)

# %%
print(id(a), id(b), id(None))

# %% [markdown]
# ## 2

# %%
a = [1, 3, 5]
b = 'This is Python'
c = {1:2, 7:9}
d = {2, 4, 6, 8}

# %%
print(1 in a, 2 not in a)

# %%
print('i' in b, 'x' in b)

# %%
print(1 in c, 2 in c)

# %%
print(2 in d, 3 in d)

# %% [markdown]
# ## 3

# %%
x = 100
y = 200
print(x > 100 != y < 200)
