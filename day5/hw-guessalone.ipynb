# %% [markdown]
# # Homework Guess Alone
#
# ## Tech
# class, for, set, input, str, cast
# ## Tasks
# 製作猜數字遊戲，由電腦隨機出 4 個不同數字讓用戶猜，每次用戶猜測的 4 個數字會由電腦輸出 ?A?B 的結果；每個遊戲在用戶完全猜對 (4A0B) 或猜測 10 次之後結束。
# ## Function & Module
# input</br>
# random</br>
# ## SPEC
# 1.程式需自訂 class 扮演電腦出題的角色，並做防呆處理。</br>
# 2.可自行獨立完成所有程式開發，亦可參考 <a href='#hello'>Reference Architecture</a> 完成所有 method。
# ## Reference Output
# <tt>
# 新遊戲開始: [7, 5, 2, 9]<br>
# round&nbsp;&nbsp;1 請猜4個數字 1234<br>
# round&nbsp;&nbsp;1: 0A 1B<br>
# round&nbsp;&nbsp;2 請猜4個數字 245 0<br>
# 輸入錯誤<br>
# round&nbsp;&nbsp;3 請猜4個數字 99aa<br>
# 輸入錯誤<br>
# round&nbsp;&nbsp;4 請猜4個數字 2345<br>
# round&nbsp;&nbsp;4: 0A 2B<br>
# round&nbsp;&nbsp;5 請猜4個數字 2322<br>
# 輸入錯誤<br>
# round&nbsp;&nbsp;6 請猜4個數字 7013<br>
# round&nbsp;&nbsp;6: 1A 0B<br>
# round&nbsp;&nbsp;7 請猜4個數字 AAAd<br>
# 輸入錯誤<br>
# round&nbsp;&nbsp;8 請猜4個數字 7592<br>
# round&nbsp;&nbsp;8: 2A 2B<br>
# round&nbsp;&nbsp;9 請猜4個數字 7529<br>
# round&nbsp;&nbsp;9: 4A
# </tt>
#
# <div id="hello"></div>
#
# ## Reference Architecture

# %%
class GuessHolder:
    
    def __init__(self, digits=4):
        pass
    
    def new(self):
        pass
    
    def get_game(self):
        pass
    
    def judge(self, guess):
        pass

    def purify(self, guess):
        pass


digits = 4
gh = GuessHolder(digits)
gh.new()
print(f'新遊戲開始: {gh.get_game()}')

for i in range(10): #  最多 10 次，避免卡關
    p = input(f'round {i+1:2} 請猜{digits}個數字 ')
    p = gh.purify(p)
    
    if not p:
        print('輸入錯誤')
        continue
    
    a, b = gh.judge(p)
    print(f'round {i+1:2}: {a}A {b}B')
    if a == 4:
        break

# %% [markdown]
# ## Solution
